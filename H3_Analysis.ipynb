# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import researchpy as rp
import scipy.stats as stats
from statsmodels.stats.anova import AnovaRM
# %matplotlib inline
# Out:
# C:\Users\Ty Gelman\Anaconda3\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.12, the latest is 0.4.0.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
pd.options.display.max_columns = 500000000
df = pd.read_csv(r"C:\Users\Ty Gelman\OneDrive\Documents\Combined_OA_Data.csv")
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
count = 0
for column in df:
    count += 1
    if count == 18:
        break
    if count >= 12: 
        H3 = df[["ID", "Sample type", column, "Modified time"]]
        H3 = H3.loc[H3['Modified time'] == 'baseline']
        #H3 = H3.dropna()
        H3[column] = pd.to_numeric(H3[column],errors='coerce')
        indexinf = H3[H3[column] == 0].index
        H3.drop(indexinf, inplace = True)
        H3[column] = np.log10(H3[column])
        print(H3.dropna())
        H3.to_csv(r'C:\Users\Ty Gelman\OneDrive\Desktop\Pandas_to_R\H3.csv', mode = 'a')
# Out:
#                  ID Sample type     MMP-2 Modified time
# 0            N1_avg          SF  4.404028      baseline
# 1            N2_avg          SF  4.467760      baseline
# 2            N3_avg          SF  4.466043      baseline
# 3            N4_avg          SF  4.223319      baseline
# 4            N5_avg          SF  4.216134      baseline
# 5            N6_avg          SF  4.087148      baseline
# 6            N7_avg          SF  4.214576      baseline
# 7            N8_avg          SF  4.315665      baseline
# 8            N9_avg          SF  4.209228      baseline
# 9        OA1-1L_avg          SF  4.265699      baseline
# 10       OA1-2L_avg          SF  4.535538      baseline
# 11       OA1-3L_avg          SF  4.282278      baseline
# 12       OA1-4L_avg          SF  4.516419      baseline
# 13       OA1-5L_avg          SF  4.322404      baseline
# 14       OA1-6L_avg          SF  4.389224      baseline
# 15       OA1-7L_avg          SF  4.351727      baseline
# ...

# %%
H3 = df[["ID", "Sample type","MMP-3", "Modified time"]]
#H3 = H3.loc[H3['Modified time'] == 'baseline']
H3 = H3.dropna()
H3
# Out:
#                  ID Sample type        MMP-3 Modified time
# 0            N1_avg          SF  1456.859000      baseline
# 1            N2_avg          SF  1379.437000      baseline
# 2            N3_avg          SF  1603.017000      baseline
# 3            N4_avg          SF  1233.441500      baseline
# 4            N5_avg          SF  1370.378000      baseline
# 5            N6_avg          SF  1542.712000      baseline
# 6            N7_avg          SF  1548.496000      baseline
# 7            N8_avg          SF  1517.412000      baseline
# 8            N9_avg          SF  1280.977000      baseline
# 9        OA1-1L_avg          SF  1399.194500      baseline
# 10       OA1-2L_avg          SF   961.665500      baseline
# 11       OA1-3L_avg          SF   770.686000      baseline
# 12       OA1-4L_avg          SF  1373.854000      baseline
# 13       OA1-5L_avg          SF   653.118500      baseline
# 14       OA1-6L_avg          SF  2049.918500      baseline
# ...

# %%
summary, results = rp.ttest(group1= H3['MMP-3'][H3['Sample type'] == 'SF'], group1_name= "SF",
                            group2= H3['MMP-3'][H3['Sample type'] == 'serum'], group2_name= "serum")

# %%
results
# Out:
#            Independent t-test    results
# 0  Difference (SF - serum) =  -1562.3256
# 1       Degrees of freedom =    665.0000
# 2                        t =     -2.4469
# 3    Two side test p value =      0.0147
# 4   Difference < 0 p value =      0.0073
# 5   Difference > 0 p value =      0.9927
# 6                Cohen's d =     -1.7328
# 7                Hedge's g =     -1.7309
# 8            Glass's delta =     -1.7316
# 9              Pearson's r =      0.0945

# %%
summary
# Out:
#    Variable      N         Mean          SD          SE   95% Conf.  \
# 0        SF  665.0   777.914472  902.257917   34.988061  709.213906
# 1     serum    2.0  2340.240088  201.560072  142.524494  529.294687
# 2  combined  667.0   782.599107  904.982670   35.041069  713.794835
#
#       Interval
# 0   846.615038
# 1  4151.185489
# 2   851.403378
