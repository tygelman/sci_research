# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import researchpy as rp
import scipy.stats as stats
from statsmodels.stats.anova import AnovaRM
# %matplotlib inline
# Out:
# C:\Users\Ty Gelman\Anaconda3\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.12, the latest is 0.4.0.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
pd.options.display.max_columns = 500000000
df = pd.read_csv(r"C:\Users\Ty Gelman\OneDrive\Documents\Combined_OA_Data.csv")
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
count = 0
for column in df:
    count += 1
    if count == 18:
        break
    if count >= 12: 
        H3 = df[["ID", "Sample type", column, "Modified time"]]
        H3 = H3.loc[H3['Modified time'] == 'baseline']
        #H3 = H3.dropna()
        H3[column] = pd.to_numeric(H3[column],errors='coerce')
        indexinf = H3[H3[column] == 0].index
        H3.drop(indexinf, inplace = True)
        H3[column] = np.log10(H3[column])
        print(H3.dropna())
        H3.to_csv(r'C:\Users\Ty Gelman\OneDrive\Desktop\Pandas_to_R\H3.csv', mode = 'a')
# Out:
#           ID Sample type     CS846 Modified time
# 649   5-0-LL          SF  2.250176      baseline
# 650   7-0-LL          SF  2.214937      baseline
# 651  10-0-LL          SF  2.229528      baseline
# 652  12-0-LL          SF  2.202298      baseline
# 653  16-0-LL          SF  2.186674      baseline
# 654  19-0-LL          SF  2.193445      baseline
# 655   6-0-LL          SF  2.215704      baseline
# 656  11-0-LL          SF  2.110893      baseline
# 657  15-0-LL          SF  2.161907      baseline
# 658  17-0-LL          SF  2.151186      baseline
# 659  18-0-LL          SF  2.088154      baseline
# 660   8-0-LL          SF  2.300389      baseline
# 661   9-0-LL          SF  2.271109      baseline
# 662  13-0-LL          SF  2.251845      baseline
# 663  14-0-LL          SF  2.211601      baseline
# 664  20-0-LL          SF  2.091579      baseline
# 665   5-0-RR          SF  2.233884      baseline
# 666   7-0-RR          SF  2.143468      baseline
# 667  10-0-RR          SF  2.175483      baseline
# 668  12-0-RR          SF  2.309492      baseline
# 669  16-0-RR          SF  2.206192      baseline
# 670  19-0-RR          SF  2.163638      baseline
# 671   6-0-RR          SF  2.196950      baseline
# 672  11-0-RR          SF  2.246572      baseline
# 673  15-0-RR          SF  2.175077      baseline
# 674  17-0-RR          SF  2.125644      baseline
# 675  18-0-RR          SF  2.147151      baseline
# 676   8-0-RR          SF  2.196356      baseline
# 677   9-0-RR          SF  2.215889      baseline
# 678  13-0-RR          SF  2.251456      baseline
# 679  14-0-RR          SF  2.146082      baseline
# 680  20-0-RR          SF  2.214778      baseline
# 809     5,0R       serum  1.991434      baseline
# 810     7,0R       serum  2.362190      baseline
# 811    10,0R       serum  2.003318      baseline
# 812    12,0R       serum  2.007667      baseline
# 813    16,0R       serum  2.058483      baseline
# 814    19,0R       serum  2.365235      baseline
# 815     6,0R       serum  1.937979      baseline
# 816    11,0R       serum  2.236915      baseline
# 817    15,0R       serum  2.325567      baseline
# 818    17,0R       serum  2.331609      baseline
# 819    18,0R       serum  2.100319      baseline
# 820     8,0R       serum  1.946683      baseline
# 821     9,0R       serum  2.664703      baseline
# 822    13,0R       serum  2.435040      baseline
# 823    14,0R       serum  2.712418      baseline
# 824    20,0R       serum  2.587717      baseline
#                  ID Sample type       IL6 Modified time
# 27          63-K-RL          SF  0.638374      baseline
# 28            66-KL          SF  0.427517      baseline
# 31             196L          SF  0.578475      baseline
# 38             217L          SF  0.015833      baseline
# 46        3-15-1-KL          SF  1.260744      baseline
# 49     9-20-OA-2-KL          SF  0.638374      baseline
# 50     9-20-OA-3-KL          SF  1.858147      baseline
# 51     9-13-OA-1-KL          SF  0.889426      baseline
# 52     8-17-OA-1-KL          SF  2.156271      baseline
# 54      5-2-OA-1-KL          SF  1.049529      baseline
# 55     6-21-OA-1-KL          SF  2.131542      baseline
# 56     6-28-OA-1-KL          SF  1.674072      baseline
# 58     4-23-OA-1-KL          SF  0.509322      baseline
# 60     4-19-OA-1-KL          SF  2.312524      baseline
# 61     4-19-OA-2-KL          SF  1.260744      baseline
# 62      4-5-OA-2-KL          SF  1.797413      baseline
# 64     4-10-OA-2-KL          SF  2.006315      baseline
# 65     3-29-OA-1-KL          SF  2.249057      baseline
# 66      5-9-OA-1-KL          SF  0.820261      baseline
# 67     5-11-OA-1-KL          SF  1.974931      baseline
# 68   6-28-OA-2-K-HL          SF  1.349767      baseline
# 69     7-10-OA-1-KL          SF  0.638374      baseline
# 70      8-2-OA-1-KL          SF  1.260744      baseline
# 72     8-20-OA-1-KL          SF  1.200699      baseline
# 73   8-21-OA-2-K-HL          SF  0.856173      baseline
# 74     8-22-OA-1-KL          SF  1.470647      baseline
# 75     9-14-OA-1-KL          SF  1.638783      baseline
# 76     9-17-OA-1-KL          SF  1.558798      baseline
# 77     9-20-OA-1-KL          SF  0.015833      baseline
# 78     11-1-OA-2-KL          SF  0.691207      baseline
# 80      235374 L SL          SF  2.156271      baseline
# 81      234026 R SL          SF  0.820261      baseline
# 82      208864 L SL          SF  1.026497      baseline
# 83   A13-22735 R SL          SF  1.971971      baseline
# 85          66-E-HL          SF  1.200699      baseline
# 90      3-15-2-E-HL          SF  1.512843      baseline
# 92     4-24-OA-2-EL          SF  0.327365      baseline
# 93     9-10-OA-2-EL          SF  0.198166      baseline
# 94      235257 L EL          SF  1.002223      baseline
# 95      235257 R EL          SF  0.820261      baseline
# 97      235236 R EL          SF  0.015833      baseline
# 99      237143 R EL          SF  0.327365      baseline
# 100     229488 R EL          SF  3.082311      baseline
# 101         63-S-HL          SF  0.327365      baseline
# 106     4-24-12-RSL          SF  1.092334      baseline
# 110   3-14-3-SH-SFL          SF  0.015833      baseline
# 120    4-18-OA-2-SL          SF  1.092334      baseline
# 121    237155 L SHL          SF  1.558798      baseline
# 122         63-H-HL          SF  0.638374      baseline
# 123         70-H-HL          SF  0.889426      baseline
# 124      243-RH-SFL          SF  0.015833      baseline
# 126    3-14-2-H-SFL          SF  0.015833      baseline
# 132     4-3-OA-1-HL          SF  0.015833      baseline
# 133    4-17-OA-1-HL          SF  1.947586      baseline
# 134    4-18-OA-4-HL          SF  1.216476      baseline
# 193           44,0L       serum  2.631022      baseline
# 197          302,0L       serum  1.137354      baseline
# 201          353,0L       serum  1.838566      baseline
# 205          430,0L       serum  1.592288      baseline
# 209          721,0L       serum  3.003073      baseline
# 213           45,0L       serum  2.358344      baseline
# 217          185,0L       serum  3.066780      baseline
# 221          271,0L       serum  2.843199      baseline
# 225          689,0L       serum  2.256044      baseline
# 229          738,0L       serum  2.027350      baseline
# 233          838,0L       serum  2.689602      baseline
# 237          177,0L       serum  1.387746      baseline
# 241          552,0L       serum  4.785397      baseline
# 245          819,0L       serum  2.657935      baseline
# 249          824,0L       serum  1.970417      baseline
# 253          904,0L       serum  2.551212      baseline
# 257            1,0L       serum  2.234619      baseline
# 261          272,0L       serum  1.927370      baseline
# 265          386,0L       serum  2.726862      baseline
# 269          817,0L       serum  2.874227      baseline
# 273          910,0L       serum  1.852632      baseline
# 601    EFS-90-0,M0R          SF  0.187393      baseline
# 604    EFS-94-0,M0R          SF -0.464444      baseline
# 607    EFS-97-0,M0R          SF  0.238639      baseline
# 610    EFS-99-0,M0R          SF  0.067276      baseline
# 613   EFS-100-0,M0R          SF  1.016893      baseline
# 616   EFS-101-0,M0R          SF  0.439825      baseline
# 622   EFS-103-0,M0R          SF  1.237500      baseline
# 625   EFS-104-0,M0R          SF  0.067276      baseline
# 628   EFS-105-0,M0R          SF  0.739718      baseline
# 634   EFS-107-0,M0R          SF  0.472342      baseline
# 637   EFS-108-0,M0R          SF  0.187393      baseline
# 643   EFS-110-0,M0R          SF  1.049989      baseline
# 654         19-0-LL          SF  0.845321      baseline
# 661          9-0-LL          SF  0.541653      baseline
#                  ID Sample type      IL-8 Modified time
# 0            N1_avg          SF  3.234179      baseline
# 1            N2_avg          SF  3.211346      baseline
# 2            N3_avg          SF  3.138746      baseline
# 3            N4_avg          SF  3.173660      baseline
# 4            N5_avg          SF  3.113955      baseline
# 5            N6_avg          SF  2.991585      baseline
# 6            N7_avg          SF  3.149051      baseline
# 7            N8_avg          SF  3.224057      baseline
# 8            N9_avg          SF  3.171009      baseline
# 9        OA1-1L_avg          SF  3.198343      baseline
# 10       OA1-2L_avg          SF  2.974824      baseline
# 11       OA1-3L_avg          SF  3.227402      baseline
# 12       OA1-4L_avg          SF  3.528019      baseline
# 13       OA1-5L_avg          SF  3.047983      baseline
# 14       OA1-6L_avg          SF  3.436076      baseline
# 15       OA1-7L_avg          SF  3.053008      baseline
# 16       OA1-8L_avg          SF  3.406576      baseline
# 17       OA1-9L_avg          SF  3.192794      baseline
# 18      OA1_10L_avg          SF  3.312708      baseline
# 31             196L          SF  1.324283      baseline
# 33             198L          SF  1.510644      baseline
# 42        3-29-1-KL          SF  1.400868      baseline
# 43         5-1-1-KL          SF  2.607836      baseline
# 55     6-21-OA-1-KL          SF  1.883397      baseline
# 56     6-28-OA-1-KL          SF  2.472462      baseline
# 57     11-7-OA-1-KL          SF  2.409462      baseline
# 60     4-19-OA-1-KL          SF  2.176624      baseline
# 61     4-19-OA-2-KL          SF  3.058787      baseline
# 62      4-5-OA-2-KL          SF  2.698522      baseline
# 64     4-10-OA-2-KL          SF  1.324283      baseline
# 69     7-10-OA-1-KL          SF  0.551402      baseline
# 70      8-2-OA-1-KL          SF  1.400868      baseline
# 73   8-21-OA-2-K-HL          SF  2.046151      baseline
# 74     8-22-OA-1-KL          SF  2.714373      baseline
# 78     11-1-OA-2-KL          SF  2.084753      baseline
# 80      235374 L SL          SF  2.129250      baseline
# 81      234026 R SL          SF  2.376417      baseline
# 85          66-E-HL          SF  2.072456      baseline
# 90      3-15-2-E-HL          SF  1.781810      baseline
# 93     9-10-OA-2-EL          SF  2.356038      baseline
# 94      235257 L EL          SF  2.882717      baseline
# 95      235257 R EL          SF  2.601788      baseline
# 96      235256 L EL          SF  1.218859      baseline
# 98      237143 L EL          SF  2.708704      baseline
# 99      237143 R EL          SF  2.486305      baseline
# 100     229488 R EL          SF  2.625284      baseline
# 106     4-24-12-RSL          SF  2.848063      baseline
# 110   3-14-3-SH-SFL          SF  1.870927      baseline
# 112        5-1-1-SL          SF  2.919184      baseline
# 121    237155 L SHL          SF  2.631805      baseline
# 122         63-H-HL          SF  2.299215      baseline
# 124      243-RH-SFL          SF  1.218859      baseline
# 126    3-14-2-H-SFL          SF  3.406749      baseline
# 127           31-HL          SF  2.739961      baseline
# 129   3-14-2-HL_avg          SF  2.438931      baseline
# 133    4-17-OA-1-HL          SF  2.474033      baseline
# 134    4-18-OA-4-HL          SF  3.121658      baseline
# 135      044, 0,OPL          SF  2.386499      baseline
# 136       302,0,OPL          SF  3.870380      baseline
# 137       353,0,OPL          SF  2.274019      baseline
# 138      430, 0,OPL          SF  2.713238      baseline
# 139       721,0,OPL          SF  2.853726      baseline
# 140       045,0,OPL          SF  2.185004      baseline
# 141       185,0,OPL          SF  2.100508      baseline
# 142       271,0,OPL          SF  2.100414      baseline
# 143       689,0,OPL          SF  2.266843      baseline
# 144       738,0,OPL          SF  2.611585      baseline
# 145       838,0,OPL          SF  2.024732      baseline
# 146       177,0,OPL          SF  2.622048      baseline
# 147       552,0,OPL          SF  2.029506      baseline
# 148       819,0,OPL          SF  2.546641      baseline
# 149       824,0,OPL          SF  2.188619      baseline
# 150       904,0,OPL          SF  1.977312      baseline
# 151       001,0,OPL          SF  2.160499      baseline
# 152       272,0,OPL          SF  3.078116      baseline
# 153       386,0,OPL          SF  2.045636      baseline
# 154       817,0,OPL          SF  2.074039      baseline
# 155       910,0,OPL          SF  1.865578      baseline
# 193           44,0L       serum  3.259211      baseline
# 197          302,0L       serum  3.617372      baseline
# 201          353,0L       serum  2.901717      baseline
# 205          430,0L       serum  3.553777      baseline
# 209          721,0L       serum  3.098176      baseline
# 213           45,0L       serum  3.176640      baseline
# 217          185,0L       serum  3.032798      baseline
# 221          271,0L       serum  3.489968      baseline
# 225          689,0L       serum  3.087542      baseline
# 229          738,0L       serum  3.046959      baseline
# 233          838,0L       serum  3.595623      baseline
# 237          177,0L       serum  3.407878      baseline
# 241          552,0L       serum  3.969220      baseline
# 245          819,0L       serum  3.393930      baseline
# 249          824,0L       serum  3.456897      baseline
# 253          904,0L       serum  3.614093      baseline
# 257            1,0L       serum  3.229577      baseline
# 261          272,0L       serum  3.864193      baseline
# 265          386,0L       serum  3.636966      baseline
# 269          817,0L       serum  3.616093      baseline
# 273          910,0L       serum  3.267313      baseline
# 613   EFS-100-0,M0R          SF  2.533007      baseline
# 619   EFS-102-0,M0R          SF  1.077406      baseline
# 622   EFS-103-0,M0R          SF  1.476553      baseline
# 625   EFS-104-0,M0R          SF  2.409157      baseline
# 631   EFS-106-0,M0R          SF  1.560347      baseline
# 640   EFS-109-0,M0R          SF  2.028224      baseline
# 643   EFS-110-0,M0R          SF  1.448581      baseline
# 649          5-0-LL          SF  2.022520      baseline
# 652         12-0-LL          SF  1.999132      baseline
# 654         19-0-LL          SF  3.231527      baseline
# 659         18-0-LL          SF  1.624296      baseline
# 660          8-0-LL          SF  1.624296      baseline
# 662         13-0-LL          SF  1.904076      baseline
# 665          5-0-RR          SF  0.645246      baseline
# 668         12-0-RR          SF  1.138952      baseline
# 669         16-0-RR          SF  2.201962      baseline
# 670         19-0-RR          SF  1.264712      baseline
# 673         15-0-RR          SF  1.138952      baseline
# 675         18-0-RR          SF  1.624296      baseline
# 678         13-0-RR          SF  1.497102      baseline
# 680         20-0-RR          SF  1.964725      baseline
#                  ID Sample type     MCP-1 Modified time
# 0            N1_avg          SF  2.222878      baseline
# 1            N2_avg          SF  2.066414      baseline
# 2            N3_avg          SF  2.017407      baseline
# 3            N4_avg          SF  1.925673      baseline
# 4            N5_avg          SF  1.976024      baseline
# 5            N6_avg          SF  1.964264      baseline
# 6            N7_avg          SF  2.119223      baseline
# 7            N8_avg          SF  1.602114      baseline
# 8            N9_avg          SF  2.013617      baseline
# 9        OA1-1L_avg          SF  1.854883      baseline
# 10       OA1-2L_avg          SF  2.691902      baseline
# 11       OA1-3L_avg          SF  2.496312      baseline
# 12       OA1-4L_avg          SF  2.690926      baseline
# 13       OA1-5L_avg          SF  2.641720      baseline
# 14       OA1-6L_avg          SF  2.628432      baseline
# 15       OA1-7L_avg          SF  2.447814      baseline
# 16       OA1-8L_avg          SF  2.758447      baseline
# 17       OA1-9L_avg          SF  2.558178      baseline
# 18      OA1_10L_avg          SF  2.669756      baseline
# 27          63-K-RL          SF  2.024289      baseline
# 28            66-KL          SF  1.918306      baseline
# 29             193L          SF  1.727042      baseline
# 30             194L          SF  1.771159      baseline
# 31             196L          SF  2.229942      baseline
# 35             211L          SF  1.929119      baseline
# 37             214L          SF  1.344251      baseline
# 38             217L          SF  1.840920      baseline
# 40            80-KL          SF  1.727042      baseline
# 41     3-14-1-K-SFL          SF  1.344251      baseline
# 43         5-1-1-KL          SF  1.993798      baseline
# 48     9-21-OA-1-KL          SF  1.808519      baseline
# 49     9-20-OA-2-KL          SF  1.918306      baseline
# 50     9-20-OA-3-KL          SF  1.641010      baseline
# 51     9-13-OA-1-KL          SF  1.958954      baseline
# 52     8-17-OA-1-KL          SF  1.808519      baseline
# 53     8-17-OA-2-KL          SF  1.771159      baseline
# 54      5-2-OA-1-KL          SF  2.509399      baseline
# 55     6-21-OA-1-KL          SF  2.741253      baseline
# 56     6-28-OA-1-KL          SF  2.496239      baseline
# 58     4-23-OA-1-KL          SF  1.507091      baseline
# 59     4-23-OA-2-KL          SF  1.603970      baseline
# 60     4-19-OA-1-KL          SF  2.922717      baseline
# 61     4-19-OA-2-KL          SF  2.087138      baseline
# 62      4-5-OA-2-KL          SF  1.808519      baseline
# 63     4-10-OA-3-KL          SF  2.063899      baseline
# 64     4-10-OA-2-KL          SF  2.220491      baseline
# 65     3-29-OA-1-KL          SF  2.154524      baseline
# 66      5-9-OA-1-KL          SF  2.170797      baseline
# 67     5-11-OA-1-KL          SF  1.808519      baseline
# 68   6-28-OA-2-K-HL          SF  2.676898      baseline
# 69     7-10-OA-1-KL          SF  2.213981      baseline
# 70      8-2-OA-1-KL          SF  1.993798      baseline
# 71     8-16-OA-1-KL          SF  1.673170      baseline
# 72     8-20-OA-1-KL          SF  1.976996      baseline
# 73   8-21-OA-2-K-HL          SF  2.118315      baseline
# 74     8-22-OA-1-KL          SF  2.264468      baseline
# 75     9-14-OA-1-KL          SF  2.009518      baseline
# 76     9-17-OA-1-KL          SF  1.808519      baseline
# 77     9-20-OA-1-KL          SF  0.627961      baseline
# 78     11-1-OA-2-KL          SF  2.075794      baseline
# 81      234026 R SL          SF  1.840920      baseline
# 82      208864 L SL          SF  2.178545      baseline
# 83   A13-22735 R SL          SF  2.336064      baseline
# 84            63-EL          SF  1.673170      baseline
# 85          66-E-HL          SF  1.976996      baseline
# 89        3-15-1-EL          SF  1.603970      baseline
# 90      3-15-2-E-HL          SF  2.477888      baseline
# 91     8-21-OA-3-EL          SF  1.918306      baseline
# 92     4-24-OA-2-EL          SF  1.344251      baseline
# 93     9-10-OA-2-EL          SF  2.550156      baseline
# 94      235257 L EL          SF  2.038218      baseline
# 95      235257 R EL          SF  2.108358      baseline
# 96      235256 L EL          SF  1.869524      baseline
# 97      235236 R EL          SF  1.840920      baseline
# 98      237143 L EL          SF  2.310774      baseline
# 99      237143 R EL          SF  2.038218      baseline
# 100     229488 R EL          SF  2.633494      baseline
# 101         63-S-HL          SF  1.869524      baseline
# 102           64-SL          SF  2.178545      baseline
# 105      2-14-12-SL          SF  2.389772      baseline
# 106     4-24-12-RSL          SF  2.763892      baseline
# 107           80-SL          SF  1.507091      baseline
# 108      243-RS-SFL          SF  1.771159      baseline
# 109      243-LS-SFL          SF  1.939474      baseline
# 110   3-14-3-SH-SFL          SF  1.906992      baseline
# 112        5-1-1-SL          SF  2.357151      baseline
# 116       3-15-2-SL          SF  1.507091      baseline
# 119    4-18-OA-1-SL          SF  1.603970      baseline
# 120    4-18-OA-2-SL          SF  0.627961      baseline
# 121    237155 L SHL          SF  2.261770      baseline
# 122         63-H-HL          SF  2.207293      baseline
# 123         70-H-HL          SF  2.127882      baseline
# 124      243-RH-SFL          SF  2.308544      baseline
# 125      246-RH-SFL          SF  1.344251      baseline
# 126    3-14-2-H-SFL          SF  1.641010      baseline
# 127           31-HL          SF  2.001784      baseline
# 129   3-14-2-HL_avg          SF  1.700754      baseline
# 132     4-3-OA-1-HL          SF  1.673170      baseline
# 133    4-17-OA-1-HL          SF  2.272388      baseline
# 134    4-18-OA-4-HL          SF  3.512570      baseline
# 135      044, 0,OPL          SF  4.244407      baseline
# 136       302,0,OPL          SF  4.058874      baseline
# 137       353,0,OPL          SF  3.989356      baseline
# 138      430, 0,OPL          SF  3.874754      baseline
# 139       721,0,OPL          SF  4.122507      baseline
# 140       045,0,OPL          SF  3.735511      baseline
# 141       185,0,OPL          SF  4.028006      baseline
# 142       271,0,OPL          SF  3.946951      baseline
# 143       689,0,OPL          SF  3.784174      baseline
# 144       738,0,OPL          SF  3.880070      baseline
# 145       838,0,OPL          SF  4.118291      baseline
# 146       177,0,OPL          SF  3.994983      baseline
# 147       552,0,OPL          SF  3.912642      baseline
# 148       819,0,OPL          SF  3.723612      baseline
# 149       824,0,OPL          SF  3.883251      baseline
# 150       904,0,OPL          SF  4.029129      baseline
# 151       001,0,OPL          SF  3.925269      baseline
# 152       272,0,OPL          SF  4.033159      baseline
# 153       386,0,OPL          SF  4.166820      baseline
# 154       817,0,OPL          SF  3.874431      baseline
# 155       910,0,OPL          SF  3.870012      baseline
# 193           44,0L       serum  2.570549      baseline
# 197          302,0L       serum  2.372267      baseline
# 201          353,0L       serum  2.372995      baseline
# 205          430,0L       serum  2.440618      baseline
# 209          721,0L       serum  2.904028      baseline
# 213           45,0L       serum  2.568255      baseline
# 217          185,0L       serum  2.535617      baseline
# 221          271,0L       serum  2.790732      baseline
# 225          689,0L       serum  2.515404      baseline
# 229          738,0L       serum  2.430099      baseline
# 233          838,0L       serum  2.614686      baseline
# 237          177,0L       serum  2.197529      baseline
# 241          552,0L       serum  3.999564      baseline
# 245          819,0L       serum  2.713381      baseline
# 249          824,0L       serum  2.497489      baseline
# 253          904,0L       serum  2.296095      baseline
# 257            1,0L       serum  2.379686      baseline
# 261          272,0L       serum  2.497662      baseline
# 265          386,0L       serum  2.746498      baseline
# 269          817,0L       serum  2.829140      baseline
# 273          910,0L       serum  2.523512      baseline
# 427      D13-126,0L          SF  2.831230      baseline
# 601    EFS-90-0,M0R          SF  1.446487      baseline
# 604    EFS-94-0,M0R          SF  1.410821      baseline
# 607    EFS-97-0,M0R          SF  1.547602      baseline
# 610    EFS-99-0,M0R          SF  1.583487      baseline
# 613   EFS-100-0,M0R          SF  1.654110      baseline
# 616   EFS-101-0,M0R          SF  0.979141      baseline
# 619   EFS-102-0,M0R          SF  0.908214      baseline
# 622   EFS-103-0,M0R          SF  1.583487      baseline
# 625   EFS-104-0,M0R          SF  1.369745      baseline
# 628   EFS-105-0,M0R          SF  1.384139      baseline
# 631   EFS-106-0,M0R          SF  1.214389      baseline
# 634   EFS-107-0,M0R          SF  1.081822      baseline
# 637   EFS-108-0,M0R          SF  0.292417      baseline
# 640   EFS-109-0,M0R          SF  0.811902      baseline
# 646   EFS-113-0,M0R          SF  1.214389      baseline
# 649          5-0-LL          SF  2.207433      baseline
# 650          7-0-LL          SF  2.273610      baseline
# 651         10-0-LL          SF  2.373394      baseline
# 652         12-0-LL          SF  2.001513      baseline
# 653         16-0-LL          SF  2.264673      baseline
# 654         19-0-LL          SF  2.320734      baseline
# 655          6-0-LL          SF  2.203749      baseline
# 656         11-0-LL          SF  2.299152      baseline
# 657         15-0-LL          SF  2.402169      baseline
# 658         17-0-LL          SF  2.164176      baseline
# 659         18-0-LL          SF  2.127347      baseline
# 660          8-0-LL          SF  2.354956      baseline
# 661          9-0-LL          SF  2.462822      baseline
# 662         13-0-LL          SF  2.183420      baseline
# 663         14-0-LL          SF  2.462822      baseline
# 664         20-0-LL          SF  2.141022      baseline
# 665          5-0-RR          SF  2.221148      baseline
# 666          7-0-RR          SF  2.362129      baseline
# 667         10-0-RR          SF  2.363293      baseline
# 668         12-0-RR          SF  2.141022      baseline
# 669         16-0-RR          SF  3.089831      baseline
# 671          6-0-RR          SF  2.255090      baseline
# 672         11-0-RR          SF  2.335382      baseline
# 673         15-0-RR          SF  2.320734      baseline
# 674         17-0-RR          SF  2.221148      baseline
# 675         18-0-RR          SF  2.111702      baseline
# 676          8-0-RR          SF  2.259969      baseline
# 677          9-0-RR          SF  2.371205      baseline
# 678         13-0-RR          SF  2.269217      baseline
# 679         14-0-RR          SF  2.273610      baseline
# 680         20-0-RR          SF  2.001513      baseline
#                  ID Sample type        KC Modified time
# 0            N1_avg          SF  2.292008      baseline
# 1            N2_avg          SF  2.461628      baseline
# 2            N3_avg          SF  2.308932      baseline
# 3            N4_avg          SF  2.325636      baseline
# 4            N5_avg          SF  2.277326      baseline
# 5            N6_avg          SF  2.175400      baseline
# 6            N7_avg          SF  2.140209      baseline
# 7            N8_avg          SF  2.252631      baseline
# 8            N9_avg          SF  2.077913      baseline
# 9        OA1-1L_avg          SF  2.173999      baseline
# 10       OA1-2L_avg          SF  2.414774      baseline
# 11       OA1-3L_avg          SF  2.455913      baseline
# 12       OA1-4L_avg          SF  2.697876      baseline
# 13       OA1-5L_avg          SF  2.294476      baseline
# 14       OA1-6L_avg          SF  2.752294      baseline
# 15       OA1-7L_avg          SF  2.748093      baseline
# 16       OA1-8L_avg          SF  2.824479      baseline
# 17       OA1-9L_avg          SF  2.393196      baseline
# 18      OA1_10L_avg          SF  2.660309      baseline
# 27          63-K-RL          SF  2.438633      baseline
# 29             193L          SF  1.536120      baseline
# 30             194L          SF  1.611838      baseline
# 31             196L          SF  1.789930      baseline
# 32             197L          SF  1.305897      baseline
# 33             198L          SF  1.789930      baseline
# 34             199L          SF  1.801970      baseline
# 36             213L          SF  2.061078      baseline
# 37             214L          SF  1.530203      baseline
# 38             217L          SF  1.931280      baseline
# 39        4-25-2-KL          SF  1.648258      baseline
# 40            80-KL          SF  1.982283      baseline
# 41     3-14-1-K-SFL          SF  1.728404      baseline
# 42        3-29-1-KL          SF  1.699649      baseline
# 43         5-1-1-KL          SF  2.091759      baseline
# 44        3-14-1-KL          SF  1.578762      baseline
# 45        3-14-2-KL          SF  1.163681      baseline
# 46        3-15-1-KL          SF  2.132363      baseline
# 47        3-15-2-KL          SF  1.281993      baseline
# 48     9-21-OA-1-KL          SF  1.875091      baseline
# 49     9-20-OA-2-KL          SF  1.907729      baseline
# 50     9-20-OA-3-KL          SF  2.020060      baseline
# 51     9-13-OA-1-KL          SF  1.841189      baseline
# 52     8-17-OA-1-KL          SF  1.950830      baseline
# 53     8-17-OA-2-KL          SF  1.504484      baseline
# 54      5-2-OA-1-KL          SF  2.346363      baseline
# 55     6-21-OA-1-KL          SF  2.280649      baseline
# 56     6-28-OA-1-KL          SF  1.888423      baseline
# 57     11-7-OA-1-KL          SF  1.158357      baseline
# 58     4-23-OA-1-KL          SF  1.660982      baseline
# 59     4-23-OA-2-KL          SF  1.759107      baseline
# 60     4-19-OA-1-KL          SF  2.156676      baseline
# 61     4-19-OA-2-KL          SF  1.618767      baseline
# 62      4-5-OA-2-KL          SF  1.869420      baseline
# 63     4-10-OA-3-KL          SF  1.782415      baseline
# 64     4-10-OA-2-KL          SF  2.246578      baseline
# 65     3-29-OA-1-KL          SF  1.971423      baseline
# 66      5-9-OA-1-KL          SF  2.235780      baseline
# 67     5-11-OA-1-KL          SF  1.872831      baseline
# 68   6-28-OA-2-K-HL          SF  2.238632      baseline
# 69     7-10-OA-1-KL          SF  1.753274      baseline
# 70      8-2-OA-1-KL          SF  2.232911      baseline
# 71     8-16-OA-1-KL          SF  1.864833      baseline
# 72     8-20-OA-1-KL          SF  2.236040      baseline
# 73   8-21-OA-2-K-HL          SF  2.167925      baseline
# 74     8-22-OA-1-KL          SF  1.956065      baseline
# 76     9-17-OA-1-KL          SF  0.222311      baseline
# 77     9-20-OA-1-KL          SF  1.493005      baseline
# 78     11-1-OA-2-KL          SF  2.550652      baseline
# 79     11-2-OA-1-KL          SF  1.621705      baseline
# 80      235374 L SL          SF  2.360967      baseline
# 81      234026 R SL          SF  1.970965      baseline
# 82      208864 L SL          SF  2.554556      baseline
# 83   A13-22735 R SL          SF  2.453364      baseline
# 84            63-EL          SF  2.116207      baseline
# 85          66-E-HL          SF  2.351281      baseline
# 86            70-EL          SF  1.812414      baseline
# 88        3-14-2-EL          SF  1.248050      baseline
# 89        3-15-1-EL          SF  1.720594      baseline
# 90      3-15-2-E-HL          SF  1.871129      baseline
# 91     8-21-OA-3-EL          SF  1.934761      baseline
# 92     4-24-OA-2-EL          SF  1.604803      baseline
# 93     9-10-OA-2-EL          SF  2.358363      baseline
# 94      235257 L EL          SF  2.017994      baseline
# 95      235257 R EL          SF  2.186479      baseline
# 96      235256 L EL          SF  1.698824      baseline
# 97      235236 R EL          SF  1.952740      baseline
# 98      237143 L EL          SF  1.439657      baseline
# 99      237143 R EL          SF  1.092232      baseline
# 100     229488 R EL          SF  3.194012      baseline
# 101         63-S-HL          SF  2.352095      baseline
# 102           64-SL          SF  2.030658      baseline
# 104           70-SL          SF  2.021295      baseline
# 106     4-24-12-RSL          SF  2.355138      baseline
# 107           80-SL          SF  1.759107      baseline
# 108      243-RS-SFL          SF  1.538465      baseline
# 109      243-LS-SFL          SF  1.793306      baseline
# 114       3-14-2-SL          SF  1.427904      baseline
# 115       3-15-1-SL          SF  1.474559      baseline
# 116       3-15-2-SL          SF  1.556812      baseline
# 117     4-2-OA-1-SL          SF  1.778264      baseline
# 118     4-3-OA-2-SL          SF  1.344950      baseline
# 119    4-18-OA-1-SL          SF  1.702115      baseline
# 120    4-18-OA-2-SL          SF  1.701294      baseline
# 121    237155 L SHL          SF  3.128277      baseline
# 122         63-H-HL          SF  3.000392      baseline
# 123         70-H-HL          SF  2.033070      baseline
# 124      243-RH-SFL          SF  1.506996      baseline
# 125      246-RH-SFL          SF  1.893867      baseline
# 126    3-14-2-H-SFL          SF  1.724516      baseline
# 127           31-HL          SF  1.690492      baseline
# 128       3-14-1-HL          SF  1.650098      baseline
# 129   3-14-2-HL_avg          SF  1.670764      baseline
# 130     3-15-1-H-HL          SF  2.027017      baseline
# 131     4-2-OA-3-HL          SF  1.854932      baseline
# 132     4-3-OA-1-HL          SF  2.041808      baseline
# 133    4-17-OA-1-HL          SF  1.916572      baseline
# 134    4-18-OA-4-HL          SF  2.165515      baseline
# 135      044, 0,OPL          SF  3.545437      baseline
# 136       302,0,OPL          SF  3.757844      baseline
# 137       353,0,OPL          SF  3.688326      baseline
# 138      430, 0,OPL          SF  3.573724      baseline
# 139       721,0,OPL          SF  3.645386      baseline
# 140       045,0,OPL          SF  3.434481      baseline
# 141       185,0,OPL          SF  3.849553      baseline
# 142       271,0,OPL          SF  3.549011      baseline
# 143       689,0,OPL          SF  3.483144      baseline
# 144       738,0,OPL          SF  3.579040      baseline
# 145       838,0,OPL          SF  3.817261      baseline
# 146       177,0,OPL          SF  3.693953      baseline
# 147       552,0,OPL          SF  3.611612      baseline
# 148       819,0,OPL          SF  3.422582      baseline
# 149       824,0,OPL          SF  3.582221      baseline
# 150       904,0,OPL          SF  3.645315      baseline
# 151       001,0,OPL          SF  3.624239      baseline
# 152       272,0,OPL          SF  3.732129      baseline
# 153       386,0,OPL          SF  3.865790      baseline
# 154       817,0,OPL          SF  3.476491      baseline
# 155       910,0,OPL          SF  3.568982      baseline
# 193           44,0L       serum  3.661118      baseline
# 197          302,0L       serum  3.088388      baseline
# 201          353,0L       serum  3.059257      baseline
# 205          430,0L       serum  2.834891      baseline
# 209          721,0L       serum  3.177062      baseline
# 213           45,0L       serum  3.014317      baseline
# 217          185,0L       serum  3.020786      baseline
# 221          271,0L       serum  2.457715      baseline
# 225          689,0L       serum  2.584179      baseline
# 229          738,0L       serum  3.180893      baseline
# 233          838,0L       serum  3.194696      baseline
# 237          177,0L       serum  3.033890      baseline
# 241          552,0L       serum  3.229973      baseline
# 245          819,0L       serum  3.259005      baseline
# 249          824,0L       serum  3.437538      baseline
# 253          904,0L       serum  2.910774      baseline
# 257            1,0L       serum  3.571890      baseline
# 261          272,0L       serum  3.462215      baseline
# 265          386,0L       serum  3.309246      baseline
# 269          817,0L       serum  2.815339      baseline
# 273          910,0L       serum  3.331025      baseline
# 283      D13-111,0L          SF  1.782329      baseline
# 289      D13-112,0L          SF  1.905688      baseline
# 295      D13-119,0L          SF  2.006637      baseline
# 307      D13-121,0L          SF  2.190724      baseline
# 313      D13-128,0L          SF  1.988559      baseline
# 331      D13-113,0L          SF  1.824256      baseline
# 337      D13-114,0L          SF  1.872156      baseline
# 367      D13-131,0L          SF  2.107685      baseline
# 379      D13-133,0L          SF  1.679791      baseline
# 385       D13-15,0L          SF  2.079398      baseline
# 391      D13-108,0L          SF  1.733358      baseline
# 397      D13-109,0L          SF  1.943396      baseline
# 421      D13-125,0L          SF  1.953180      baseline
# 427      D13-126,0L          SF  2.168497      baseline
# 433      D13-127,0L          SF  1.955495      baseline
# 445      D13-111,0R          SF  1.909235      baseline
# 451      D13-112,0R          SF  1.852480      baseline
# 457      D13-113,0R          SF  1.903958      baseline
# 463      D13-114,0R          SF  1.814381      baseline
# 475       D13-15,0R          SF  1.880814      baseline
# 487      D13-109,0R          SF  1.712986      baseline
# 493      D13-119,0R          SF  1.811039      baseline
# 505      D13-121,0R          SF  2.170907      baseline
# 511      D13-128,0R          SF  1.945074      baseline
# 523      D13-130,0R          SF  1.717171      baseline
# 547      D13-125,0R          SF  1.914555      baseline
# 553      D13-126,0R          SF  1.854428      baseline
# 583      D13-131,0R          SF  2.150695      baseline
# 595      D13-133,0R          SF  1.756636      baseline
# 601    EFS-90-0,M0R          SF  1.389905      baseline
# 604    EFS-94-0,M0R          SF  1.146581      baseline
# 607    EFS-97-0,M0R          SF  1.183102      baseline
# 610    EFS-99-0,M0R          SF  1.699400      baseline
# 613   EFS-100-0,M0R          SF  1.887072      baseline
# 616   EFS-101-0,M0R          SF  0.465184      baseline
# 619   EFS-102-0,M0R          SF  0.676949      baseline
# 622   EFS-103-0,M0R          SF  1.213671      baseline
# 625   EFS-104-0,M0R          SF  1.861689      baseline
# 628   EFS-105-0,M0R          SF  1.843032      baseline
# 631   EFS-106-0,M0R          SF  1.265034      baseline
# 634   EFS-107-0,M0R          SF  1.347634      baseline
# 637   EFS-108-0,M0R          SF  1.237519      baseline
# 640   EFS-109-0,M0R          SF  1.614959      baseline
# 643   EFS-110-0,M0R          SF  1.637244      baseline
# 646   EFS-113-0,M0R          SF  1.372404      baseline
# 649          5-0-LL          SF  2.301929      baseline
# 650          7-0-LL          SF  2.578101      baseline
# 651         10-0-LL          SF  2.415892      baseline
# 652         12-0-LL          SF  2.574808      baseline
# 653         16-0-LL          SF  2.606554      baseline
# 654         19-0-LL          SF  2.711953      baseline
# 655          6-0-LL          SF  2.353613      baseline
# 656         11-0-LL          SF  2.596317      baseline
# 657         15-0-LL          SF  2.188196      baseline
# 658         17-0-LL          SF  2.433274      baseline
# 659         18-0-LL          SF  1.377246      baseline
# 660          8-0-LL          SF  2.720626      baseline
# 661          9-0-LL          SF  2.499394      baseline
# 662         13-0-LL          SF  2.390785      baseline
# 663         14-0-LL          SF  2.691549      baseline
# 664         20-0-LL          SF  2.388911      baseline
# 665          5-0-RR          SF  2.365618      baseline
# 666          7-0-RR          SF  2.635846      baseline
# 667         10-0-RR          SF  2.417660      baseline
# 668         12-0-RR          SF  2.248941      baseline
# 669         16-0-RR          SF  2.567512      baseline
# 670         19-0-RR          SF  2.466217      baseline
# 671          6-0-RR          SF  2.402780      baseline
# 672         11-0-RR          SF  2.665883      baseline
# 673         15-0-RR          SF  2.283377      baseline
# 674         17-0-RR          SF  2.319965      baseline
# 675         18-0-RR          SF  1.814800      baseline
# 676          8-0-RR          SF  2.656461      baseline
# 677          9-0-RR          SF  2.522001      baseline
# 678         13-0-RR          SF  2.559844      baseline
# 679         14-0-RR          SF  2.643328      baseline
# 680         20-0-RR          SF  2.297362      baseline
#                  ID Sample type     MMP-2 Modified time
# 0            N1_avg          SF  4.404028      baseline
# 1            N2_avg          SF  4.467760      baseline
# 2            N3_avg          SF  4.466043      baseline
# 3            N4_avg          SF  4.223319      baseline
# 4            N5_avg          SF  4.216134      baseline
# 5            N6_avg          SF  4.087148      baseline
# 6            N7_avg          SF  4.214576      baseline
# 7            N8_avg          SF  4.315665      baseline
# 8            N9_avg          SF  4.209228      baseline
# 9        OA1-1L_avg          SF  4.265699      baseline
# 10       OA1-2L_avg          SF  4.535538      baseline
# 11       OA1-3L_avg          SF  4.282278      baseline
# 12       OA1-4L_avg          SF  4.516419      baseline
# 13       OA1-5L_avg          SF  4.322404      baseline
# 14       OA1-6L_avg          SF  4.389224      baseline
# 15       OA1-7L_avg          SF  4.351727      baseline
# 16       OA1-8L_avg          SF  4.167792      baseline
# 17       OA1-9L_avg          SF  4.353568      baseline
# 18      OA1_10L_avg          SF  4.270539      baseline
# 27          63-K-RL          SF  4.193839      baseline
# 28            66-KL          SF  4.364708      baseline
# 29             193L          SF  1.997957      baseline
# 30             194L          SF  4.571104      baseline
# 31             196L          SF  4.615226      baseline
# 32             197L          SF  4.364956      baseline
# 33             198L          SF  4.550584      baseline
# 34             199L          SF  4.525260      baseline
# 35             211L          SF  4.547898      baseline
# 37             214L          SF  4.584842      baseline
# 38             217L          SF  4.574560      baseline
# 39        4-25-2-KL          SF  4.686566      baseline
# 40            80-KL          SF  4.491723      baseline
# 41     3-14-1-K-SFL          SF  4.646759      baseline
# 42        3-29-1-KL          SF  4.574492      baseline
# 43         5-1-1-KL          SF  4.550137      baseline
# 44        3-14-1-KL          SF  4.523774      baseline
# 46        3-15-1-KL          SF  4.459097      baseline
# 47        3-15-2-KL          SF  4.529044      baseline
# 48     9-21-OA-1-KL          SF  4.653615      baseline
# 49     9-20-OA-2-KL          SF  4.535619      baseline
# 50     9-20-OA-3-KL          SF  4.561644      baseline
# 51     9-13-OA-1-KL          SF  4.716118      baseline
# 52     8-17-OA-1-KL          SF  4.214707      baseline
# 53     8-17-OA-2-KL          SF  4.552418      baseline
# 54      5-2-OA-1-KL          SF  4.576134      baseline
# 55     6-21-OA-1-KL          SF  4.582502      baseline
# 56     6-28-OA-1-KL          SF  4.553268      baseline
# 57     11-7-OA-1-KL          SF  4.650080      baseline
# 58     4-23-OA-1-KL          SF  4.477028      baseline
# 59     4-23-OA-2-KL          SF  4.583546      baseline
# 60     4-19-OA-1-KL          SF  4.634322      baseline
# 61     4-19-OA-2-KL          SF  4.707684      baseline
# 62      4-5-OA-2-KL          SF  4.515491      baseline
# 63     4-10-OA-3-KL          SF  4.545320      baseline
# 64     4-10-OA-2-KL          SF  4.560237      baseline
# 69     7-10-OA-1-KL          SF  4.698733      baseline
# 70      8-2-OA-1-KL          SF  4.598945      baseline
# 73   8-21-OA-2-K-HL          SF  4.063629      baseline
# 74     8-22-OA-1-KL          SF  4.479046      baseline
# 77     9-20-OA-1-KL          SF  4.513498      baseline
# 78     11-1-OA-2-KL          SF  4.485251      baseline
# 80      235374 L SL          SF  4.338460      baseline
# 81      234026 R SL          SF  4.151275      baseline
# 82      208864 L SL          SF  4.390209      baseline
# 83   A13-22735 R SL          SF  3.858381      baseline
# 84            63-EL          SF  4.598054      baseline
# 85          66-E-HL          SF  4.636015      baseline
# 88        3-14-2-EL          SF  4.736020      baseline
# 89        3-15-1-EL          SF  4.541030      baseline
# 90      3-15-2-E-HL          SF  0.561116      baseline
# 91     8-21-OA-3-EL          SF  4.545163      baseline
# 94      235257 L EL          SF  2.825436      baseline
# 95      235257 R EL          SF  3.558248      baseline
# 96      235256 L EL          SF  4.498315      baseline
# 97      235236 R EL          SF  4.494216      baseline
# 100     229488 R EL          SF  2.308976      baseline
# 101         63-S-HL          SF  3.784524      baseline
# 102           64-SL          SF  4.095737      baseline
# 103           66-SL          SF  4.319591      baseline
# 104           70-SL          SF  4.402345      baseline
# 105      2-14-12-SL          SF  4.288656      baseline
# 106     4-24-12-RSL          SF  4.557021      baseline
# 107           80-SL          SF  4.443760      baseline
# 108      243-RS-SFL          SF  4.544692      baseline
# 109      243-LS-SFL          SF  4.638539      baseline
# 110   3-14-3-SH-SFL          SF  4.354125      baseline
# 111       3-29-1-SL          SF  4.464125      baseline
# 112        5-1-1-SL          SF  4.164932      baseline
# 113       3-14-1-SL          SF  4.387229      baseline
# 114       3-14-2-SL          SF  4.611905      baseline
# 115       3-15-1-SL          SF  4.426164      baseline
# 116       3-15-2-SL          SF  4.308900      baseline
# 118     4-3-OA-2-SL          SF  4.599204      baseline
# 119    4-18-OA-1-SL          SF  4.295406      baseline
# 120    4-18-OA-2-SL          SF  3.959139      baseline
# 122         63-H-HL          SF  4.184875      baseline
# 123         70-H-HL          SF  4.889348      baseline
# 124      243-RH-SFL          SF  4.649057      baseline
# 125      246-RH-SFL          SF  2.003021      baseline
# 126    3-14-2-H-SFL          SF  4.688131      baseline
# 127           31-HL          SF  4.575976      baseline
# 128       3-14-1-HL          SF  4.558383      baseline
# 129   3-14-2-HL_avg          SF  4.567269      baseline
# 130     3-15-1-H-HL          SF  4.105278      baseline
# 131     4-2-OA-3-HL          SF  4.659963      baseline
# 132     4-3-OA-1-HL          SF  4.318255      baseline
# 133    4-17-OA-1-HL          SF  0.875995      baseline
# 277      D13-110,0L          SF  4.710693      baseline
# 283      D13-111,0L          SF  4.853357      baseline
# 289      D13-112,0L          SF  4.307838      baseline
# 295      D13-119,0L          SF  4.310098      baseline
# 301      D13-120,0L          SF  4.677059      baseline
# 307      D13-121,0L          SF  4.707757      baseline
# 313      D13-128,0L          SF  4.559931      baseline
# 319      D13-129,0L          SF  4.520405      baseline
# 325      D13-130,0L          SF  4.559404      baseline
# 331      D13-113,0L          SF  4.724358      baseline
# 337      D13-114,0L          SF  4.635242      baseline
# 343      D13-115,0L          SF  4.417339      baseline
# 349      D13-122,0L          SF  4.467134      baseline
# 355      D13-123,0L          SF  4.832023      baseline
# 361      D13-124,0L          SF  4.516324      baseline
# 367      D13-131,0L          SF  4.628082      baseline
# 373      D13-132,0L          SF  4.697822      baseline
# 379      D13-133,0L          SF  4.535724      baseline
# 385       D13-15,0L          SF  4.726629      baseline
# 391      D13-108,0L          SF  4.484670      baseline
# 397      D13-109,0L          SF  4.850021      baseline
# 403      D13-116,0L          SF  4.612784      baseline
# 409      D13-117,0L          SF  4.739177      baseline
# 415      D13-118,0L          SF  4.800854      baseline
# 421      D13-125,0L          SF  4.509364      baseline
# 427      D13-126,0L          SF  4.793399      baseline
# 433      D13-127,0L          SF  4.729408      baseline
# 439      D13-110,0R          SF  4.822417      baseline
# 445      D13-111,0R          SF  4.663908      baseline
# 451      D13-112,0R          SF  4.731476      baseline
# 457      D13-113,0R          SF  4.652324      baseline
# 463      D13-114,0R          SF  4.743667      baseline
# 469      D13-115,0R          SF  4.670264      baseline
# 475       D13-15,0R          SF  4.833899      baseline
# 481      D13-108,0R          SF  4.696898      baseline
# 487      D13-109,0R          SF  4.797724      baseline
# 493      D13-119,0R          SF  4.715402      baseline
# 499      D13-120,0R          SF  4.790187      baseline
# 505      D13-121,0R          SF  4.589860      baseline
# 511      D13-128,0R          SF  4.635041      baseline
# 517      D13-129,0R          SF  4.707161      baseline
# 523      D13-130,0R          SF  4.761567      baseline
# 529      D13-116,0R          SF  4.771749      baseline
# 535      D13-117,0R          SF  4.741876      baseline
# 541      D13-118,0R          SF  4.539528      baseline
# 547      D13-125,0R          SF  4.511375      baseline
# 553      D13-126,0R          SF  4.663022      baseline
# 559      D13-127,0R          SF  4.782802      baseline
# 565      D13-122,0R          SF  4.751248      baseline
# 571      D13-123,0R          SF  4.732313      baseline
# 577      D13-124,0R          SF  4.570613      baseline
# 583      D13-131,0R          SF  4.432617      baseline
# 589      D13-132,0R          SF  4.667023      baseline
# 595      D13-133,0R          SF  4.639407      baseline
# 601    EFS-90-0,M0R          SF  3.895186      baseline
# 604    EFS-94-0,M0R          SF  4.076461      baseline
# 607    EFS-97-0,M0R          SF  4.123320      baseline
# 610    EFS-99-0,M0R          SF  3.937406      baseline
# 613   EFS-100-0,M0R          SF  3.822715      baseline
# 616   EFS-101-0,M0R          SF  3.952125      baseline
# 619   EFS-102-0,M0R          SF  3.809190      baseline
# 622   EFS-103-0,M0R          SF  4.124926      baseline
# 625   EFS-104-0,M0R          SF  3.223786      baseline
# 628   EFS-105-0,M0R          SF  3.762680      baseline
# 631   EFS-106-0,M0R          SF  3.861231      baseline
# 634   EFS-107-0,M0R          SF  3.982766      baseline
# 637   EFS-108-0,M0R          SF  4.011845      baseline
# 640   EFS-109-0,M0R          SF  4.000343      baseline
# 643   EFS-110-0,M0R          SF  3.913380      baseline
# 646   EFS-113-0,M0R          SF  4.032275      baseline
# 649          5-0-LL          SF  4.763038      baseline
# 650          7-0-LL          SF  4.625507      baseline
# 651         10-0-LL          SF  5.022341      baseline
# 652         12-0-LL          SF  4.650682      baseline
# 653         16-0-LL          SF  4.625923      baseline
# 654         19-0-LL          SF  2.785534      baseline
# 655          6-0-LL          SF  4.673311      baseline
# 656         11-0-LL          SF  4.876863      baseline
# 657         15-0-LL          SF  4.035027      baseline
# 658         17-0-LL          SF  4.674011      baseline
# 659         18-0-LL          SF  4.939169      baseline
# 660          8-0-LL          SF  4.793078      baseline
# 661          9-0-LL          SF  5.006191      baseline
# 662         13-0-LL          SF  4.110908      baseline
# 663         14-0-LL          SF  4.386458      baseline
# 664         20-0-LL          SF  4.665339      baseline
# 665          5-0-RR          SF  4.643746      baseline
# 666          7-0-RR          SF  4.735700      baseline
# 667         10-0-RR          SF  4.900157      baseline
# 668         12-0-RR          SF  4.470732      baseline
# 669         16-0-RR          SF  4.618433      baseline
# 670         19-0-RR          SF  4.728559      baseline
# 671          6-0-RR          SF  4.603014      baseline
# 672         11-0-RR          SF  4.944287      baseline
# 673         15-0-RR          SF  4.317287      baseline
# 674         17-0-RR          SF  4.660458      baseline
# 675         18-0-RR          SF  4.747080      baseline
# 676          8-0-RR          SF  4.888497      baseline
# 677          9-0-RR          SF  5.082217      baseline
# 678         13-0-RR          SF  3.995910      baseline
# 679         14-0-RR          SF  4.443058      baseline
# 680         20-0-RR          SF  4.774097      baseline

# %%
H3 = df[["ID", "Sample type","IL-8", "Modified time"]]
H3 = H3.loc[H3['Modified time'] == 'baseline']
H3 = H3.dropna()
H3
# Out:
#                  ID Sample type         IL-8 Modified time
# 0            N1_avg          SF    1714.6625      baseline
# 1            N2_avg          SF    1626.8425      baseline
# 2            N3_avg          SF     1376.405      baseline
# 3            N4_avg          SF     1491.625      baseline
# 4            N5_avg          SF     1300.035      baseline
# 5            N6_avg          SF       980.81      baseline
# 6            N7_avg          SF     1409.455      baseline
# 7            N8_avg          SF    1675.1625      baseline
# 8            N9_avg          SF      1482.55      baseline
# 9        OA1-1L_avg          SF   1578.85625      baseline
# 10       OA1-2L_avg          SF     943.6775      baseline
# 11       OA1-3L_avg          SF    1688.1135      baseline
# 12       OA1-4L_avg          SF    3373.0185      baseline
# 13       OA1-5L_avg          SF      1116.82      baseline
# 14       OA1-6L_avg          SF    2729.4545      baseline
# 15       OA1-7L_avg          SF     1129.817      baseline
# 16       OA1-8L_avg          SF    2550.2085      baseline
# 17       OA1-9L_avg          SF    1558.8135      baseline
# 18      OA1_10L_avg          SF     2054.511      baseline
# 27          63-K-RL          SF            0      baseline
# 28            66-KL          SF            0      baseline
# 29             193L          SF            0      baseline
# 30             194L          SF            0      baseline
# 31             196L          SF  21.10003278      baseline
# 32             197L          SF            0      baseline
# 33             198L          SF  32.40741497      baseline
# 34             199L          SF            0      baseline
# 35             211L          SF            0      baseline
# 36             213L          SF            0      baseline
# 37             214L          SF            0      baseline
# 38             217L          SF            0      baseline
# 39        4-25-2-KL          SF            0      baseline
# 40            80-KL          SF            0      baseline
# 41     3-14-1-K-SFL          SF            0      baseline
# 42        3-29-1-KL          SF  25.16910707      baseline
# 43         5-1-1-KL          SF  405.3558834      baseline
# 44        3-14-1-KL          SF            0      baseline
# 45        3-14-2-KL          SF            0      baseline
# 46        3-15-1-KL          SF            0      baseline
# 47        3-15-2-KL          SF            0      baseline
# 48     9-21-OA-1-KL          SF            0      baseline
# 49     9-20-OA-2-KL          SF            0      baseline
# 50     9-20-OA-3-KL          SF            0      baseline
# 51     9-13-OA-1-KL          SF            0      baseline
# 52     8-17-OA-1-KL          SF            0      baseline
# 53     8-17-OA-2-KL          SF            0      baseline
# 54      5-2-OA-1-KL          SF            0      baseline
# 55     6-21-OA-1-KL          SF  76.45341372      baseline
# 56     6-28-OA-1-KL          SF  296.7987772      baseline
# 57     11-7-OA-1-KL          SF  256.7213496      baseline
# 58     4-23-OA-1-KL          SF            0      baseline
# 59     4-23-OA-2-KL          SF            0      baseline
# 60     4-19-OA-1-KL          SF  150.1839699      baseline
# 61     4-19-OA-2-KL          SF  1144.951824      baseline
# 62      4-5-OA-2-KL          SF  499.4841737      baseline
# 63     4-10-OA-3-KL          SF            0      baseline
# 64     4-10-OA-2-KL          SF  21.10003278      baseline
# 65     3-29-OA-1-KL          SF            0      baseline
# 66      5-9-OA-1-KL          SF            0      baseline
# 67     5-11-OA-1-KL          SF            0      baseline
# 68   6-28-OA-2-K-HL          SF            0      baseline
# 69     7-10-OA-1-KL          SF  3.559608523      baseline
# 70      8-2-OA-1-KL          SF  25.16910707      baseline
# 71     8-16-OA-1-KL          SF            0      baseline
# 72     8-20-OA-1-KL          SF            0      baseline
# 73   8-21-OA-2-K-HL          SF  111.2118139      baseline
# 74     8-22-OA-1-KL          SF   518.052081      baseline
# 75     9-14-OA-1-KL          SF            0      baseline
# 76     9-17-OA-1-KL          SF            0      baseline
# 77     9-20-OA-1-KL          SF            0      baseline
# 78     11-1-OA-2-KL          SF  121.5494149      baseline
# 79     11-2-OA-1-KL          SF            0      baseline
# 80      235374 L SL          SF  134.6634372      baseline
# 81      234026 R SL          SF   237.912562      baseline
# 82      208864 L SL          SF            0      baseline
# 83   A13-22735 R SL          SF            0      baseline
# 84            63-EL          SF            0      baseline
# 85          66-E-HL          SF  118.1560843      baseline
# 86            70-EL          SF            0      baseline
# 88        3-14-2-EL          SF            0      baseline
# 89        3-15-1-EL          SF            0      baseline
# 90      3-15-2-E-HL          SF  60.50754829      baseline
# 91     8-21-OA-3-EL          SF            0      baseline
# 92     4-24-OA-2-EL          SF            0      baseline
# 93     9-10-OA-2-EL          SF  227.0061132      baseline
# 94      235257 L EL          SF  763.3378965      baseline
# 95      235257 R EL          SF  399.7492722      baseline
# 96      235256 L EL          SF  16.55231872      baseline
# 97      235236 R EL          SF            0      baseline
# 98      237143 L EL          SF  511.3328863      baseline
# 99      237143 R EL          SF  306.4114685      baseline
# 100     229488 R EL          SF  421.9724566      baseline
# 101         63-S-HL          SF            0      baseline
# 102           64-SL          SF            0      baseline
# 103           66-SL          SF            0      baseline
# 104           70-SL          SF            0      baseline
# 105      2-14-12-SL          SF            0      baseline
# 106     4-24-12-RSL          SF  704.7953719      baseline
# 107           80-SL          SF            0      baseline
# 108      243-RS-SFL          SF            0      baseline
# 109      243-LS-SFL          SF            0      baseline
# 110   3-14-3-SH-SFL          SF  74.28943287      baseline
# 112        5-1-1-SL          SF  830.2026931      baseline
# 114       3-14-2-SL          SF            0      baseline
# 115       3-15-1-SL          SF            0      baseline
# 116       3-15-2-SL          SF            0      baseline
# 117     4-2-OA-1-SL          SF            0      baseline
# 118     4-3-OA-2-SL          SF            0      baseline
# 119    4-18-OA-1-SL          SF            0      baseline
# 120    4-18-OA-2-SL          SF            0      baseline
# 121    237155 L SHL          SF   428.356088      baseline
# 122         63-H-HL          SF  199.1658248      baseline
# 123         70-H-HL          SF            0      baseline
# 124      243-RH-SFL          SF  16.55231872      baseline
# 125      246-RH-SFL          SF            0      baseline
# 126    3-14-2-H-SFL          SF  2551.228337      baseline
# 127           31-HL          SF  549.4912985      baseline
# 128       3-14-1-HL          SF            0      baseline
# 129   3-14-2-HL_avg          SF  274.7456493      baseline
# 130     3-15-1-H-HL          SF            0      baseline
# 131     4-2-OA-3-HL          SF            0      baseline
# 132     4-3-OA-1-HL          SF            0      baseline
# 133    4-17-OA-1-HL          SF  297.8741137      baseline
# 134    4-18-OA-4-HL          SF   1323.29887      baseline
# 135      044, 0,OPL          SF        243.5      baseline
# 136       302,0,OPL          SF      7419.59      baseline
# 137       353,0,OPL          SF       187.94      baseline
# 138      430, 0,OPL          SF        516.7      baseline
# 139       721,0,OPL          SF      714.045      baseline
# 140       045,0,OPL          SF       153.11      baseline
# 141       185,0,OPL          SF       126.04      baseline
# 142       271,0,OPL          SF     126.0125      baseline
# 143       689,0,OPL          SF       184.86      baseline
# 144       738,0,OPL          SF       408.87      baseline
# 145       838,0,OPL          SF       105.86      baseline
# 146       177,0,OPL          SF       418.84      baseline
# 147       552,0,OPL          SF       107.03      baseline
# 148       819,0,OPL          SF       352.08      baseline
# 149       824,0,OPL          SF       154.39      baseline
# 150       904,0,OPL          SF        94.91      baseline
# 151       001,0,OPL          SF       144.71      baseline
# 152       272,0,OPL          SF      1197.06      baseline
# 153       386,0,OPL          SF       111.08      baseline
# 154       817,0,OPL          SF     118.5875      baseline
# 155       910,0,OPL          SF        73.38      baseline
# 193           44,0L       serum       1816.4      baseline
# 197          302,0L       serum      4143.54      baseline
# 201          353,0L       serum      797.475      baseline
# 205          430,0L       serum     3579.125      baseline
# 209          721,0L       serum      1253.65      baseline
# 213           45,0L       serum     1501.895      baseline
# 217          185,0L       serum     1078.445      baseline
# 221          271,0L       serum     3090.065      baseline
# 225          689,0L       serum     1223.325      baseline
# 229          738,0L       serum      1114.19      baseline
# 233          838,0L       serum      3941.15      baseline
# 237          177,0L       serum     2557.865      baseline
# 241          552,0L       serum     9315.795      baseline
# 245          819,0L       serum      2477.02      baseline
# 249          824,0L       serum       2863.5      baseline
# 253          904,0L       serum     4112.375      baseline
# 257            1,0L       serum      1696.59      baseline
# 261          272,0L       serum     7314.645      baseline
# 265          386,0L       serum     4334.765      baseline
# 269          817,0L       serum     4131.355      baseline
# 273          910,0L       serum       1850.6      baseline
# 277      D13-110,0L          SF            0      baseline
# 283      D13-111,0L          SF            0      baseline
# 289      D13-112,0L          SF            0      baseline
# 295      D13-119,0L          SF            0      baseline
# 301      D13-120,0L          SF            0      baseline
# 307      D13-121,0L          SF            0      baseline
# 313      D13-128,0L          SF            0      baseline
# 319      D13-129,0L          SF            0      baseline
# 325      D13-130,0L          SF            0      baseline
# 331      D13-113,0L          SF            0      baseline
# 337      D13-114,0L          SF            0      baseline
# 343      D13-115,0L          SF            0      baseline
# 349      D13-122,0L          SF            0      baseline
# 355      D13-123,0L          SF            0      baseline
# 361      D13-124,0L          SF            0      baseline
# 367      D13-131,0L          SF            0      baseline
# 373      D13-132,0L          SF            0      baseline
# 379      D13-133,0L          SF            0      baseline
# 385       D13-15,0L          SF            0      baseline
# 391      D13-108,0L          SF            0      baseline
# 397      D13-109,0L          SF            0      baseline
# 403      D13-116,0L          SF            0      baseline
# 409      D13-117,0L          SF            0      baseline
# 415      D13-118,0L          SF            0      baseline
# 421      D13-125,0L          SF            0      baseline
# 427      D13-126,0L          SF            0      baseline
# 433      D13-127,0L          SF            0      baseline
# 439      D13-110,0R          SF            0      baseline
# 445      D13-111,0R          SF            0      baseline
# 451      D13-112,0R          SF            0      baseline
# 457      D13-113,0R          SF            0      baseline
# 463      D13-114,0R          SF            0      baseline
# 475       D13-15,0R          SF            0      baseline
# 481      D13-108,0R          SF            0      baseline
# 487      D13-109,0R          SF            0      baseline
# 493      D13-119,0R          SF            0      baseline
# 499      D13-120,0R          SF            0      baseline
# 505      D13-121,0R          SF            0      baseline
# 511      D13-128,0R          SF            0      baseline
# 517      D13-129,0R          SF            0      baseline
# 523      D13-130,0R          SF            0      baseline
# 529      D13-116,0R          SF            0      baseline
# 535      D13-117,0R          SF            0      baseline
# 541      D13-118,0R          SF            0      baseline
# 547      D13-125,0R          SF            0      baseline
# 553      D13-126,0R          SF            0      baseline
# 559      D13-127,0R          SF            0      baseline
# 565      D13-122,0R          SF            0      baseline
# 571      D13-123,0R          SF            0      baseline
# 577      D13-124,0R          SF            0      baseline
# 583      D13-131,0R          SF            0      baseline
# 589      D13-132,0R          SF            0      baseline
# 595      D13-133,0R          SF            0      baseline
# 601    EFS-90-0,M0R          SF            0      baseline
# 604    EFS-94-0,M0R          SF            0      baseline
# 607    EFS-97-0,M0R          SF            0      baseline
# 610    EFS-99-0,M0R          SF            0      baseline
# 613   EFS-100-0,M0R          SF  341.1981846      baseline
# 616   EFS-101-0,M0R          SF            0      baseline
# 619   EFS-102-0,M0R          SF  11.95103582      baseline
# 622   EFS-103-0,M0R          SF  29.96073894      baseline
# 625   EFS-104-0,M0R          SF  256.5410779      baseline
# 628   EFS-105-0,M0R          SF            0      baseline
# 631   EFS-106-0,M0R          SF  36.33685132      baseline
# 634   EFS-107-0,M0R          SF            0      baseline
# 637   EFS-108-0,M0R          SF            0      baseline
# 640   EFS-109-0,M0R          SF  106.7146004      baseline
# 643   EFS-110-0,M0R          SF  28.09189353      baseline
# 646   EFS-113-0,M0R          SF            0      baseline
# 649          5-0-LL          SF  105.3221406      baseline
# 650          7-0-LL          SF            0      baseline
# 651         10-0-LL          SF            0      baseline
# 652         12-0-LL          SF  99.80043705      baseline
# 653         16-0-LL          SF            0      baseline
# 654         19-0-LL          SF  1704.226309      baseline
# 655          6-0-LL          SF            0      baseline
# 656         11-0-LL          SF            0      baseline
# 657         15-0-LL          SF            0      baseline
# 658         17-0-LL          SF            0      baseline
# 659         18-0-LL          SF  42.10136598      baseline
# 660          8-0-LL          SF  42.10136598      baseline
# 661          9-0-LL          SF            0      baseline
# 662         13-0-LL          SF  80.18178784      baseline
# 663         14-0-LL          SF            0      baseline
# 664         20-0-LL          SF            0      baseline
# 665          5-0-RR          SF  4.418201674      baseline
# 666          7-0-RR          SF            0      baseline
# 667         10-0-RR          SF            0      baseline
# 668         12-0-RR          SF  13.77057941      baseline
# 669         16-0-RR          SF  159.2070816      baseline
# 670         19-0-RR          SF  18.39549675      baseline
# 671          6-0-RR          SF            0      baseline
# 672         11-0-RR          SF            0      baseline
# 673         15-0-RR          SF  13.77057941      baseline
# 674         17-0-RR          SF            0      baseline
# 675         18-0-RR          SF  42.10136598      baseline
# 676          8-0-RR          SF            0      baseline
# 677          9-0-RR          SF            0      baseline
# 678         13-0-RR          SF  31.41248515      baseline
# 679         14-0-RR          SF            0      baseline
# 680         20-0-RR          SF  92.19878611      baseline

# %%
summary, results = rp.ttest(group1= H3['MMP-2'][H3['Sample type'] == 'SF'], group1_name= "SF",
                            group2= H3['MMP-2'][H3['Sample type'] == 'serum'], group2_name= "serum")

# %%
results
# Out:
#            Independent t-test  results
# 0  Difference (SF - serum) =       NaN
# 1       Degrees of freedom =     223.0
# 2                        t =       NaN
# 3    Two side test p value =       NaN
# 4   Difference < 0 p value =       NaN
# 5   Difference > 0 p value =       NaN
# 6                Cohen's d =       NaN
# 7                Hedge's g =       NaN
# 8            Glass's delta =       NaN
# 9              Pearson's r =       NaN

# %%
summary
# Out:
#    Variable      N         Mean            SD           SE     95% Conf.  \
# 0        SF  225.0  37145.85245  21114.589334  1407.639289  34371.943038
# 1     serum    0.0          NaN           NaN          NaN           NaN
# 2  combined  225.0  37145.85245  21114.589334  1407.639289  34371.943038
#
#        Interval
# 0  39919.761862
# 1           NaN
# 2  39919.761862
