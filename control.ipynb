# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import researchpy as rp
import scipy.stats as stats
from statsmodels.stats.anova import AnovaRM
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
pd.options.display.max_columns = 500000000
df = pd.read_csv(r"C:\Users\Ty Gelman\OneDrive\Desktop\Geotaxis_Control.csv")
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#                 Trial  Testing Round Exercise Group Diet Group  \
# 0   WT_Control_Trial1              1             NE         ND
# 1   WT_Control_Trial1              1             NE         DR
# 2   WT_Control_Trial1              1             ME         ND
# 3   WT_Control_Trial1              1             ME         DR
# 4   WT_Control_Trial1              1             SE         ND
# 5   WT_Control_Trial1              1             SE         DR
# 6   WT_Control_Trial2              1             NE         ND
# 7   WT_Control_Trial2              1             NE         DR
# 8   WT_Control_Trial2              1             ME         ND
# 9   WT_Control_Trial2              1             ME         DR
# 10  WT_Control_Trial2              1             SE         ND
# 11  WT_Control_Trial2              1             SE         DR
# 12  WT_Control_Trial3              1             NE         ND
# 13  WT_Control_Trial3              1             NE         DR
# 14  WT_Control_Trial3              1             ME         ND
# 15  WT_Control_Trial3              1             ME         DR
# 16  WT_Control_Trial3              1             SE         ND
# 17  WT_Control_Trial3              1             SE         DR
#
#     Day 5 Geotaxis Times (Seconds)  Day 10 Geotaxis Times (Seconds)  \
# 0                             2.15                             2.05
# 1                             2.53                             2.50
# 2                             1.89                             2.70
# 3                             3.08                             3.23
# 4                             3.77                             4.60
# 5                             2.39                             4.46
# 6                             2.36                             1.96
# 7                             2.51                             2.40
# 8                             3.47                             3.46
# 9                             3.43                             3.10
# 10                            2.51                             7.93
# 11                            4.10                             4.37
# 12                            2.44                             2.74
# 13                            2.16                             1.82
# 14                            3.14                             3.46
# 15                            3.05                             3.44
# 16                            1.97                             6.47
# 17                            3.33                             3.98
#
#     Day 15 Geotaxis Times (Seconds)  Day 20 Geotaxis Times (Seconds)  \
# 0                              4.28                             4.63
# 1                              3.47                             7.55
# 2                              9.41                             8.95
# 3                             10.83                            11.90
# 4                             16.69                            18.90
# 5                              6.31                             8.80
# 6                              6.37                             5.12
# 7                              3.07                             9.91
# 8                              5.10                             9.26
# 9                              5.97                            12.01
# 10                            15.12                            17.70
# 11                             5.19                             8.19
# 12                             4.62                             4.89
# 13                             2.66                            10.10
# 14                             7.20                             8.77
# 15                             8.60                            11.32
# 16                            18.30                            21.80
# 17                             7.81                            11.32
#
#     Day 25 Geotaxis Times (Seconds)  Average Times (Across Trials)
# 0                              7.90                          4.202
# 1                              9.30                          5.070
# 2                             13.20                          7.230
# 3                             12.80                          8.368
# 4                             21.40                         13.072
# 5                             12.30                          6.852
# 6                              9.12                          4.986
# 7                             14.00                          6.378
# 8                             12.14                          6.686
# 9                             13.02                          7.506
# 10                            21.78                         13.008
# 11                            15.60                          7.490
# 12                            12.30                          5.398
# 13                            15.60                          6.468
# 14                            11.80                          6.874
# 15                            14.68                          8.218
# 16                            28.80                         15.468
# 17                            17.81                          8.850
