# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import researchpy as rp
import scipy.stats as stats
from statsmodels.stats.anova import AnovaRM
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
pd.options.display.max_columns = 500000000
df = pd.read_csv(r"C:\Users\Ty Gelman\OneDrive\Desktop\Geotaxis_Muscle.csv")
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#                         Trial  Testing Round Exercise Diet  \
# 0   SMA_Muscle_Trial1,1-NE-ND              1       NE   ND
# 1   SMA_Muscle_Trial1,1-NE-DR              1       NE   DR
# 2   SMA_Muscle_Trial1,1-ME-ND              1       ME   ND
# 3   SMA_Muscle_Trial1,1-ME-DR              1       ME   DR
# 4   SMA_Muscle_Trial1,1-SE-ND              1       SE   ND
# 5   SMA_Muscle_Trial1,1-SE-DR              1       SE   DR
# 6   SMA_Muscle_Trial2,1-NE-ND              1       NE   ND
# 7   SMA_Muscle_Trial2,1-NE-DR              1       NE   DR
# 8   SMA_Muscle_Trial2,1-ME-ND              1       ME   ND
# 9   SMA_Muscle_Trial2,1-ME-DR              1       ME   DR
# 10  SMA_Muscle_Trial2,1-SE-ND              1       SE   ND
# 11  SMA_Muscle_Trial2,1-SE-DR              1       SE   DR
# 12  SMA_Muscle_Trial3,1-NE-ND              1       NE   ND
# 13  SMA_Muscle_Trial3,1-NE-DR              1       NE   DR
# 14  SMA_Muscle_Trial3,1-ME-ND              1       ME   ND
# 15  SMA_Muscle_Trial3,1-ME-DR              1       ME   DR
# 16  SMA_Muscle_Trial3,1-SE-ND              1       SE   ND
# 17  SMA_Muscle_Trial3,1-SE-DR              1       SE   DR
# 18  SMA_Muscle_Trial1,2-NE-ND              2       NE   ND
# 19  SMA_Muscle_Trial1,2-NE-DR              2       NE   DR
# 20  SMA_Muscle_Trial1,2-ME-ND              2       ME   ND
# 21  SMA_Muscle_Trial1,2-ME-DR              2       ME   DR
# 22  SMA_Muscle_Trial1,2-SE-ND              2       SE   ND
# 23  SMA_Muscle_Trial1,2-SE-DR              2       SE   DR
# 24  SMA_Muscle_Trial2,2-NE-ND              2       NE   ND
# 25  SMA_Muscle_Trial2,2-NE-DR              2       NE   DR
# 26  SMA_Muscle_Trial2,2-ME-ND              2       ME   ND
# 27  SMA_Muscle_Trial2,2-ME-DR              2       ME   DR
# 28  SMA_Muscle_Trial2,2-SE-ND              2       SE   ND
# 29  SMA_Muscle_Trial2,2-SE-DR              2       SE   DR
# 30  SMA_Muscle_Trial3,2-NE-ND              2       NE   ND
# 31  SMA_Muscle_Trial3,2-NE-DR              2       NE   DR
# 32  SMA_Muscle_Trial3,2-ME-ND              2       ME   ND
# 33  SMA_Muscle_Trial3,2-ME-DR              2       ME   DR
# 34  SMA_Muscle_Trial3,2-SE-ND              2       SE   ND
# 35  SMA_Muscle_Trial3,2-SE-DR              2       SE   DR
#
#     Day 5 Geotaxis Times (Seconds)  Day 10 Geotaxis Times (Seconds)  \
# 0                             1.71                             1.93
# 1                             1.37                             2.07
# 2                             1.17                             6.21
# 3                             2.33                             2.73
# 4                             1.03                             2.27
# 5                             1.75                             2.20
# 6                             1.85                             2.20
# 7                             2.04                             2.75
# 8                             1.49                             3.82
# 9                             2.05                             2.41
# 10                            1.36                             1.92
# 11                            1.50                             1.47
# 12                            2.19                             1.93
# 13                            2.34                             2.64
# 14                            1.73                             3.78
# 15                            3.21                             1.94
# 16                            1.66                             1.91
# 17                            1.12                             1.55
# 18                            2.15                             2.05
# 19                            2.53                             2.50
# 20                            1.89                             2.70
# 21                            3.08                             3.23
# 22                            3.77                             4.60
# 23                            2.39                             4.46
# 24                            2.36                             1.96
# 25                            2.51                             2.40
# 26                            3.47                             3.46
# 27                            3.43                             3.10
# 28                            2.51                             7.93
# 29                            4.10                             4.37
# 30                            2.44                             2.74
# 31                            2.16                             1.82
# 32                            3.14                             3.46
# 33                            3.05                             3.44
# 34                            1.97                             6.47
# 35                            3.33                             3.98
#
#     Day 15 Geotaxis Times (Seconds)  Day 20 Geotaxis Times (Seconds)  \
# 0                              4.30                             5.20
# 1                              5.35                             6.48
# 2                              6.57                            60.00
# 3                              4.08                             6.46
# 4                             14.20                            60.00
# 5                              3.92                             3.40
# 6                             12.64                            60.00
# 7                              2.70                             4.92
# 8                              6.90                            60.00
# 9                              3.74                             7.86
# 10                            17.20                            60.00
# 11                             3.06                             5.67
# 12                             7.68                            60.00
# 13                             3.44                             6.05
# 14                             5.84                            60.00
# 15                             5.58                             4.51
# 16                            20.10                            60.00
# 17                             2.87                             3.45
# 18                             4.28                             4.63
# 19                             3.47                             7.55
# 20                             9.41                             8.95
# 21                            10.83                            11.90
# 22                            16.69                            60.00
# 23                             6.31                            60.00
# 24                             6.37                             5.12
# 25                             3.07                             9.91
# 26                             5.10                             9.26
# 27                             5.97                            12.01
# 28                            15.12                            60.00
# 29                             5.19                            60.00
# 30                             4.62                             4.89
# 31                             2.66                            10.10
# 32                             7.20                             8.77
# 33                             8.60                            11.32
# 34                            18.30                            60.00
# 35                             7.81                            60.00
#
#     Day 25 Geotaxis Times (Seconds)  Average Time Across Trials
# 0                             13.30                       5.288
# 1                             60.00                      15.054
# 2                             60.00                      26.790
# 3                             10.76                       5.272
# 4                             60.00                      27.500
# 5                             13.40                       4.934
# 6                             60.00                      27.338
# 7                             60.00                      14.482
# 8                             60.00                      26.442
# 9                             13.20                       5.852
# 10                            60.00                      28.096
# 11                            10.36                       4.412
# 12                            60.00                      26.360
# 13                            60.00                      14.894
# 14                            60.00                      26.270
# 15                            11.15                       5.278
# 16                            60.00                      28.734
# 17                             9.15                       3.628
# 18                            60.00                      14.622
# 19                            60.00                      15.210
# 20                            60.00                      16.590
# 21                            12.80                       8.368
# 22                            60.00                      29.012
# 23                            60.00                      26.632
# 24                            60.00                      15.162
# 25                            60.00                      15.578
# 26                            60.00                      16.258
# 27                            13.02                       7.506
# 28                            60.00                      29.112
# 29                            60.00                      26.732
# 30                            60.00                      14.938
# 31                            60.00                      15.348
# 32                            60.00                      16.514
# 33                            14.68                       8.218
# 34                            60.00                      29.348
# 35                            60.00                      27.024

# %%
aovrm2way = AnovaRM(df, 'Average Time Across Trials', 'Trial', within=['Exercise', 'Diet'])
print(aovrm2way.fit())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\TYGELM~1\AppData\Local\Temp/ipykernel_28796/770188597.py in <module>
#       1 aovrm2way = AnovaRM(df, 'Average Time Across Trials', 'Trial', within=['Exercise', 'Diet'])
# ----> 2 print(aovrm2way.fit())
#
# ~\Conda\lib\site-packages\statsmodels\stats\anova.py in fit(self)
#     571         results = model.fit()
#     572         if model.rank < x.shape[1]:
# --> 573             raise ValueError('Independent variables are collinear.')
#     574         for i in term_exclude:
#     575             term_slices.pop(i)
#
# ValueError: Independent variables are collinear.

# %%
aovrm2way
